# %% [markdown]
# <a href="https://colab.research.google.com/github/MarcinJanCiesielski/data_science_bootcamp/blob/main/06_Uczenie_maszynowe/04_regresja_liniowa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
np.random.seed(10)

X = np.arange(0, 50, 0.5)
noise = 10 * np.random.randn(100)
y = 2 * X + 100 + noise
X = X.reshape(-1, 1)

print('Rozmiar X:',X.shape)
print('Rozmiar y:', y.shape)
# Out:
# Rozmiar X: (100, 1)
# Rozmiar y: (100,)

# %% [markdown]
# #Podział danych na zbiór treningowy i testowy

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

print('X_train shape:', X_train.shape)
print('X_test shape:', X_test.shape)
print('y_train_shape', y_train.shape)
print('y_test shape', y_test.shape)
# Out:
# X_train shape: (75, 1)
# X_test shape: (25, 1)
# y_train_shape (75,)
# y_test shape (25,)

# %% [markdown]
# #Wizualizacja

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

plt.figure(figsize=(7, 5))
plt.scatter(X_train, y_train, c='b', label='Zbiór treningowy')
plt.scatter(X_test, y_test, c='g', label='Zbiór testowy')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()

# %% [markdown]
# #Regresja liniowa

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)

print(lin_reg.coef_)
print(lin_reg.intercept_)
# Out:
# [1.93438329]
# 101.86187237393071

# %% [markdown]
# #Wizualizacja zbioru treningowego i dopasowanego modelu

# %%
plt.figure(figsize=(7, 5))
plt.title('Regresja Liniowa - jedna zmienna')
plt.scatter(X_train, y_train, c='b', label='Zbiór treningowy')
plt.plot(X, lin_reg.intercept_ + lin_reg.coef_[0] * X, c='red')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()

# %% [markdown]
# #Wizualizacja zbioru testowego i dopasowanego modelu

# %%
y_pred = lin_reg.predict(X_test)
plt.figure(figsize=(7, 5))
plt.title('Regresja Liniowa - jedna zmienna')
plt.scatter(X_test, y_test, c='g', label='Zbiór testowy')
plt.plot(X, lin_reg.intercept_ + lin_reg.coef_[0] * X, c='red')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()

# %% [markdown]
# #Ocena modelu

# %%
lin_reg.score(X_test, y_test)
# Out:
# 0.8773651467468433

# %% [markdown]
# #Przykład złego zastosowania regresji liniowej

# %%
X = np.arange(-5, 5, 0.5)
noise = 10 * np.random.randn(20)
y = 2 * (X ** 2) + 4 + noise
X = X.reshape(-1, 1)

lin_reg = LinearRegression()
lin_reg.fit(X, y)

print(lin_reg.coef_)
print(lin_reg.intercept_)

plt.figure(figsize=(7, 5))
plt.title('Regresja Liniowa - jedna zmienna')
plt.plot(X, lin_reg.intercept_ + lin_reg.coef_[0] * X, c='red')
plt.scatter(X, y)
plt.xlabel('X')
plt.ylabel('y')

#dane nie ustawiają się wzdłuż linii i nie da się zastosować regresji liniowej
# Out:
# [-2.00321952]
# 15.970490013839077
# Text(0, 0.5, 'y')
